# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from google.colab import drive
import os
from os import listdir
from os.path import isfile, join
import cv2
import matplotlib.pyplot as plt



os.chdir("/content/drive/MyDrive/SS(NOW)/content/cars-moviepy")

img = cv2.imread('frame0.jpg')
plt.imshow(img)  
os.chdir("/content/drive/MyDrive/YOLOV4(New)/content")

import glob

# %%
import pandas as pd
from google.colab import drive
import os
from os import listdir
from os.path import isfile, join
import cv2
import matplotlib.pyplot as plt

drive.mount("/content/drive")
os.chdir("/content/drive/MyDrive/SS(NOW)/content/cars-moviepy")

img = cv2.imread('frame0.jpg')
plt.imshow(img)  
os.chdir("/content/drive/MyDrive/YOLOV4(New)/content")

import glob


W=1920
H=1080

k=0
color = (0, 0, 255)
thickness = 2

color2 = (0, 255, 0)
thickness2 = 5

for f in(glob.glob("*")):
  print(f)
  data = pd.read_csv(f)
  for i in range(len(data)-1):
    start_point=(int(W-data['xcentre'][i]),int(data['ycentre'][i]))
    end_point=(int(W-data['xcentre'][i+1]),int(data['ycentre'][i+1]))
    if(i==0):
      img = cv2.line(img, start_point, end_point, color2, thickness2)
    else:
      img = cv2.line(img, start_point, end_point, color, thickness)
    print(color)
  k=k+50
  color=(k,0,255)
  color2=(k,255,0)
os.chdir("/content/drive/MyDrive/RESULTS")
cv2.imwrite('res1.png',img)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# YOLOV22(RESEARCH)(50).csv
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# (0, 0, 255)
# YOLOV94(RESEARCH)(50).csv
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# (50, 0, 255)
# ...

# %%
import pandas as pd
from google.colab import drive
import os
from os import listdir
from os.path import isfile, join
import cv2
import matplotlib.pyplot as plt


os.chdir("/content/drive/MyDrive/SS(NOW)/content/cars-moviepy")

img = cv2.imread('frame0.jpg')
plt.imshow(img)  
os.chdir("/content/drive/MyDrive/TRACK(YOLOV4_NOW)/content")

import glob
import numpy as np

W=1920
H=1080


color = (0, 0, 255)
thickness = 2

color2 = (0, 255, 0)
thickness2 = 5
fps=20
fps_track=4
for f in(glob.glob("*")):
  print(f)
  os.chdir("/content/drive/MyDrive/TRACK(YOLOV4_NOW)/content")
  data = pd.read_csv(f)
  print(data)
  max_frame=int(np.max(data['Frame']*fps_track))
  print(max_frame)
  start=0
  while(max_frame>start):
    fName='frame'+str(start)+'.jpg'
    print(fName)
    os.chdir("/content/drive/MyDrive/SS(NOW)/content/cars-moviepy")
    img = cv2.imread(fName)
    sub_data=data[data['Frame']*fps_track<=start]
    print(sub_data)
    print('len:'+str(len(data)))
    for i in range(len(data)-1):
      current_frame=int(data['Frame'][i]*fps_track)
      #print('current_frame:'+str(current_frame))
      if(current_frame>start):
        os.chdir("/content/drive/MyDrive/RESULTS")
        cv2.imwrite(fName,img)
        start=start+fps
        break
      start_point=(int(W-data['xcentre'][i]),int(data['ycentre'][i]))
      end_point=(int(W-data['xcentre'][i+1]),int(data['ycentre'][i+1]))
      if(i==0):
        img = cv2.line(img, start_point, end_point, color2, thickness2)
      else:
        img = cv2.line(img, start_point, end_point, color, thickness)
# Out:
# Streaming output truncated to the last 5000 lines.
# 96    152           5   car   1080.0   1035.0
# 97    153           5   car   1075.0   1040.5
# 98    154           5   car   1078.5   1046.0
# 99    155           5   car   1076.5   1054.5
#
# [100 rows x 5 columns]
# len:101
# frame620.jpg
#     Frame  Tracker_id Class  xcentre  ycentre
# 0       3           5   car    761.5    504.5
# 1       4           5   car    765.0    506.0
# 2       5           5   car    769.0    509.5
# 3       6           5   car    774.0    512.5
# 4       7           5   car    778.5    516.5
# ..    ...         ...   ...      ...      ...
# 95    151           5   car   1073.5   1031.5
# 96    152           5   car   1080.0   1035.0
# 97    153           5   car   1075.0   1040.5
# 98    154           5   car   1078.5   1046.0
# 99    155           5   car   1076.5   1054.5
#
# [100 rows x 5 columns]
# len:101
# frame620.jpg
#     Frame  Tracker_id Class  xcentre  ycentre
# ...
