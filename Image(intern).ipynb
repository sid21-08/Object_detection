# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1=pd.read_csv("/content/drive/MyDrive/ALGORITHMS(CV)/BYTETRACK(900-UP)/content/Tracker1(ALL)(50).csv")

# %%
df1.head()
# Out:
#    Frame  Tracker_id  xcentre  ycentre
# 0      1           1    263.5    167.0
# 1      2           1    264.5    166.0
# 2      3           1    266.0    166.0
# 3      4           1    267.5    166.0
# 4      5           1    269.0    164.5

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
im = plt.imread("/content/Films__TV_31-08-2022_01_17_12(NEW).png")
fig, ax = plt.subplots()
im = ax.imshow(im, extent=[0, 1000, 0, 1000])

x = df1['xcentre']
y = df1['ycentre']
z = df1['Frame']
ax.plot(x, y, z, ls='solid', linewidth=2, color='red')
plt.show()

# %%
import cv2

# %%
im=cv2.imread("/content/Films__TV_31-08-2022_01_17_12(NEW).png")
print(im.shape)
# Out:
# (1080, 1920, 3)

# %%
w,h,c=im.shape

# %%
from google.colab.patches import cv2_imshow

# %%
import os
dir_path=r'/content/drive/MyDrive/ALGORITHMS(CV)/YOLOV4(TRACK)'
count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('File count:', count)
# Out:
# File count: 13

# %%
image = cv2.imread('/content/Films__TV_31-08-2022_01_17_12(NEW).png')
for j in range(0,count):
  df1=pd.read_csv(f"/content/drive/MyDrive/ALGORITHMS(CV)/YOLOV4(TRACK)/Tracker{j}(YOLOV4)(900).csv")
  for i in range(1,len(df1)):
    st=df1.iloc[i-1]
    x1,y1=h-st['xcentre'],w-st['ycentre']
    en=df1.iloc[i]
    x2,y2=h-en['xcentre'],w-en['ycentre']
    line_thickness = 10
    cv2.line(image, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), thickness=line_thickness)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7FCA5CD35B50>

# %%
image = cv2.imread('/content/Films__TV_31-08-2022_01_17_12(NEW).png')
height, width, channels = image.shape
for i in zip(x,y):
  
startpoint = (0, 0)
endpoint = (height, width)
thickness = 9
color = (255, 0, 0)
image = cv2.line(image, startpoint, endpoint, color, thickness)
cv2.imshow('Line', image)
Output
# Out:
#   File "<ipython-input-13-c4eb650fb0d9>", line 5
#     startpoint = (0, 0)
#              ^
# IndentationError: expected an indented block

# %%
im = plt.imread("/content/Films__TV_31-08-2022_01_17_12(NEW).png")
fig, ax = plt.subplots()
im = ax.imshow(im)
for i in zip(x,y):
  plt.scatter(h-i[0],w-i[1],color='red')
  #print(i)
plt.axis('off')
plt.show()

# %%
im.width
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-b76141916627> in <module>
# ----> 1 im.width
#
# AttributeError: 'AxesImage' object has no attribute 'width'

# %%
from matplotlib import image
from matplotlib import pyplot as plt

# %%
data = image.imread('/content/Films__TV_25-08-2022_00_42_49.png')
for i in df1:
  x1=[df1['xcentre'],df1['ycentre']]
